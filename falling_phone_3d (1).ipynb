# %%
"""
Author: Cameron Ogiugo

This document aims to create a 3d scatter plot of data from Falltest2.csv

Required Files:

Falltest2.csv
"""
# Out:
# '\nAuthor: Cameron Ogiugo\n\nThe below document was created to analyse the accelaration of a falling phone on various test datasets.\nThe phone was dropped from a height of 1.5m and fell on a couch approximately 0.6m high from the ground.\n\nIn this document I also aimed to creat standard deviations and means which I could use to plan the creation\nof the detecting program. I viewed it in a histogram plot created using seaborn.\n\nIt reads the data from a csv file created using the Physics Toolbox sensor suite.\n\nRequired Files:\nFalltest1.csv\nFalltest2.csv\nFalltest3.csv\n'

# %%
# %matplotlib notebook

# %%
# import all modules necessary
import numpy as np 
import seaborn as sns
from numpy.random import normal
from datetime import datetime
import matplotlib.pyplot as plt
import math
import pandas as pd

# %%
data = pd.read_csv('Falltest2.csv') # We read the data using pandas
time1 = (data['time'])
ax = (data['ax'])
ay = (data['ay'])
az = (data['az'])
atotal = (data['atotal'])

# %%
fig3 = plt.figure(figsize=(4,4) )
ax3= fig3.add_subplot(projection='3d')

ax3.scatter(np.log(ax), np.log(ay), np.log(az), c=az, cmap='autumn', linewidth=0.4, edgecolor='gray')



ax3.set_xlabel('ax ($m/s^2$)')
ax3.set_ylabel('ay ($m/s^2$)')
ax3.set_zlabel('az ($m/s^2$)')

ax3.azim = 15
ax3.dist = 10
ax3.elev = 35
plt.title('Plot Of Components Of Acceleration Of 2nd Phone Drop', weight='bold')
plt.show()

fig3.savefig('3dfallphone.png', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="400">
# C:\Users\camer\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\camer\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
